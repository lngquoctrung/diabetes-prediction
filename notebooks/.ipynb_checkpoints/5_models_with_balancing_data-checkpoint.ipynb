# %% [markdown]
# ## **0. Library import**

# %%
import os
import sys

# Add the root path into the python path
root_path = os.path.abspath(os.path.join(".."))
if not root_path in sys.path:
    sys.path.insert(0, root_path)

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from src.config import BRFSS_FILTERING_FILE_PATH, TRAIN_SIZE, RANDOM_STATE, N_JOBS, \
    OVER_SAMPLING_STRATEGY, UNDER_SAMPLING_STRATEGY, \
    SGD_ALPHA, SGD_MAX_ITER, SGD_LOSS, SGD_PENALTY, SGD_LEARNING_RATE, \
    LR_C, LR_PENALTY, LR_CLASS_WEIGHT, LR_VERBOSE, LR_MAX_ITER, LR_SOLVER, \
    RF_N_ESTIMATORS, RF_MAX_DEPTH, \
    NB_ALPHA, NB_TYPE, NB_BINARIZE, NB_VAR_SMOOTHING
from src.evaluate import plot_roc_auc, compare_models
from src.features import DiabetesFeatureEngineering
from src.balancing.over_sampler import OverSamplingBalancer
from src.balancing.under_sampler import UnderSamplingBalancer
from src.balancing.hyprid import HybridSamplingBalancer
from src.models import DiabetesSGDClassifier, DiabetesLogisticRegression, DiabetesRandomForest, DiabetesNaiveBayes

# %% [markdown]
# ## **1. Load dataset**

# %%
# Load dataset
df = pd.read_csv(BRFSS_FILTERING_FILE_PATH)
df.shape
# Out:
# (787602, 21)

# %% [markdown]
# ## **2. Feature engineering**

# %%
# Apply feature engineering on orignal dataset
diabetes_feature_engineering = DiabetesFeatureEngineering()
processed_df, encoder_dict, processed_columns = diabetes_feature_engineering.process_all(df)
# Out:
# 2025-07-30 12:48:19,891 - [src.features] - INFO - DiabetesFeatureEngineering initialized successfully
# 2025-07-30 12:48:19,893 - [src.features] - INFO - ============================================================
# 2025-07-30 12:48:19,894 - [src.features] - INFO - STARTING COMPLETE FEATURE ENGINEERING PIPELINE
# 2025-07-30 12:48:19,895 - [src.features] - INFO - ============================================================
# 2025-07-30 12:48:19,895 - [src.features] - INFO - Initial dataset shape: (787602, 21)
# 2025-07-30 12:48:19,896 - [src.features] - INFO - Starting null values removal process...
# 2025-07-30 12:48:19,912 - [src.features] - INFO - No null values found in the dataset
# 2025-07-30 12:48:19,961 - [src.features] - INFO - Null values removal completed. Removed 0 rows (0.00%)
# 2025-07-30 12:48:19,962 - [src.features] - INFO - Dataset shape: 787602 -> 787602 rows
# 2025-07-30 12:48:19,962 - [src.features] - INFO - After null removal: (787602, 21)
# 2025-07-30 12:48:19,963 - [src.features] - INFO - Starting duplicate removal process...
# 2025-07-30 12:48:20,149 - [src.features] - INFO - Found 85086 duplicate rows
# 2025-07-30 12:48:20,385 - [src.features] - INFO - Duplicate removal completed. Removed 85086 rows (10.80%)
# 2025-07-30 12:48:20,386 - [src.features] - INFO - Dataset shape: 787602 -> 702516 rows
# 2025-07-30 12:48:20,386 - [src.features] - INFO - After duplicate removal: (702516, 21)
# 2025-07-30 12:48:20,387 - [src.features] - INFO - Starting outlier handling process...
# 2025-07-30 12:48:20,387 - [src.features] - INFO - Columns to process: ['BMI', 'MentHlth', 'PhysHlth']
# 2025-07-30 12:48:20,404 - [src.features] - INFO - Processing outliers for column: BMI
# 2025-07-30 12:48:20,422 - [src.features] - INFO -   - Total outliers: 18685 (Lower: 0, Upper: 18685)
# 2025-07-30 12:48:20,427 - [src.features] - INFO - Processing outliers for column: MentHlth
# 2025-07-30 12:48:20,442 - [src.features] - INFO -   - Total outliers: 90551 (Lower: 0, Upper: 90551)
# 2025-07-30 12:48:20,448 - [src.features] - INFO - Processing outliers for column: PhysHlth
# 2025-07-30 12:48:20,463 - [src.features] - INFO -   - Total outliers: 105104 (Lower: 0, Upper: 105104)
# 2025-07-30 12:48:20,469 - [src.features] - INFO - Outlier handling completed. Total outliers handled: 214340
# 2025-07-30 12:48:20,470 - [src.features] - INFO - Creating health score feature...
# 2025-07-30 12:48:20,494 - [src.features] - INFO - Health score created successfully. Range: [0.200, 1.667]
# 2025-07-30 12:48:20,495 - [src.features] - INFO - Creating risk score feature...
# 2025-07-30 12:48:20,600 - [src.features] - INFO - Risk score created successfully using 4 features. Range: [0.0, 4.0]
# 2025-07-30 12:48:20,601 - [src.features] - INFO - Creating lifestyle score feature...
# 2025-07-30 12:48:20,744 - [src.features] - INFO - Lifestyle score created successfully using 1 positive and 2 negative factors
# 2025-07-30 12:48:20,747 - [src.features] - INFO - Range: [-2.0, 1.0]
# 2025-07-30 12:48:20,748 - [src.features] - INFO - Creating cardiovascular risk feature...
# 2025-07-30 12:48:20,810 - [src.features] - INFO - Cardiovascular risk created successfully using: ['HighBP', 'HighChol', 'BMI_Obesity']
# 2025-07-30 12:48:20,812 - [src.features] - INFO - Range: [0.0, 3.0]
# 2025-07-30 12:48:20,813 - [src.features] - INFO - Creating healthy lifestyle feature...
# 2025-07-30 12:48:20,960 - [src.features] - INFO - Healthy lifestyle feature created using 1 positive and 2 negative factors
# 2025-07-30 12:48:20,963 - [src.features] - INFO - Range: [-2.0, 1.0]
# 2025-07-30 12:48:20,963 - [src.features] - INFO - Creating BMI category feature...
# 2025-07-30 12:48:21,142 - [src.features] - INFO - BMI category distribution:
# 2025-07-30 12:48:21,143 - [src.features] - INFO -   - Pre-obesity: 243286 (34.63%)
# 2025-07-30 12:48:21,143 - [src.features] - INFO -   - Normal weight: 170548 (24.28%)
# 2025-07-30 12:48:21,144 - [src.features] - INFO -   - Obesity class I: 160806 (22.89%)
# 2025-07-30 12:48:21,144 - [src.features] - INFO -   - Obesity class II: 70206 (9.99%)
# 2025-07-30 12:48:21,144 - [src.features] - INFO -   - Obesity class III: 47594 (6.77%)
# 2025-07-30 12:48:21,145 - [src.features] - INFO -   - Underweight: 10076 (1.43%)
# 2025-07-30 12:48:21,145 - [src.features] - INFO - Creating age group feature...
# 2025-07-30 12:48:21,294 - [src.features] - INFO - Age group distribution:
# 2025-07-30 12:48:21,294 - [src.features] - INFO -   - Senior: 345527 (49.18%)
# 2025-07-30 12:48:21,295 - [src.features] - INFO -   - Middle: 269648 (38.38%)
# 2025-07-30 12:48:21,295 - [src.features] - INFO -   - Young: 87341 (12.43%)
# 2025-07-30 12:48:21,296 - [src.features] - INFO - After feature creation: (702516, 28)
# 2025-07-30 12:48:21,297 - [src.features] - INFO - Starting categorical feature encoding...
# 2025-07-30 12:48:21,331 - [src.features] - INFO - Found 2 categorical columns to encode: ['BMICategory', 'AgeGroup']
# 2025-07-30 12:48:21,331 - [src.features] - INFO - Encoding column: BMICategory
# 2025-07-30 12:48:21,396 - [src.features] - INFO -   - Encoding mapping: {'Normal weight': 0, 'Obesity class I': 1, 'Obesity class II': 2, 'Obesity class III': 3, 'Pre-obesity': 4, 'Underweight': 5}
# 2025-07-30 12:48:21,396 - [src.features] - INFO - Encoding column: AgeGroup
# 2025-07-30 12:48:21,456 - [src.features] - INFO -   - Encoding mapping: {'Middle': 0, 'Senior': 1, 'Young': 2}
# 2025-07-30 12:48:21,457 - [src.features] - INFO - Categorical feature encoding completed
# 2025-07-30 12:48:21,459 - [src.features] - INFO - After categorical encoding: (702516, 28)
# 2025-07-30 12:48:21,459 - [src.features] - INFO - Starting feature selection process...
# 2025-07-30 12:48:21,460 - [src.features] - INFO - Target column: Diabetes
# 2025-07-30 12:48:21,460 - [src.features] - INFO - Correlation threshold: 0.1
# 2025-07-30 12:48:22,568 - [src.features] - INFO - Selected 14 features (+ target column)
# 2025-07-30 12:48:22,568 - [src.features] - INFO - Selected features and their correlations:
# 2025-07-30 12:48:22,569 - [src.features] - INFO -   - HighBP: 0.2641
# 2025-07-30 12:48:22,569 - [src.features] - INFO -   - HighChol: 0.2109
# 2025-07-30 12:48:22,569 - [src.features] - INFO -   - BMI: 0.2134
# 2025-07-30 12:48:22,570 - [src.features] - INFO -   - Stroke: 0.1005
# 2025-07-30 12:48:22,570 - [src.features] - INFO -   - HeartDiseaseorAttack: 0.1709
# 2025-07-30 12:48:22,570 - [src.features] - INFO -   - PhysActivity: -0.1140
# 2025-07-30 12:48:22,570 - [src.features] - INFO -   - GenHlth: 0.2728
# 2025-07-30 12:48:22,571 - [src.features] - INFO -   - PhysHlth: 0.1528
# 2025-07-30 12:48:22,571 - [src.features] - INFO -   - DiffWalk: 0.2064
# 2025-07-30 12:48:22,571 - [src.features] - INFO -   - Age: 0.2029
# 2025-07-30 12:48:22,571 - [src.features] - INFO -   - Income: -0.1331
# 2025-07-30 12:48:22,572 - [src.features] - INFO -   - HlthScore: 0.2236
# 2025-07-30 12:48:22,572 - [src.features] - INFO -   - RiskScore: 0.3159
# 2025-07-30 12:48:22,572 - [src.features] - INFO -   - CardioRisk: 0.3253
# 2025-07-30 12:48:22,587 - [src.features] - INFO - Final dataset shape: (702516, 15)
# 2025-07-30 12:48:22,588 - [src.features] - INFO - ============================================================
# 2025-07-30 12:48:22,588 - [src.features] - INFO - FEATURE ENGINEERING PIPELINE COMPLETED
# 2025-07-30 12:48:22,588 - [src.features] - INFO - ============================================================
# 2025-07-30 12:48:22,588 - [src.features] - INFO - Dataset transformation: (787602, 21) -> (702516, 15)
# 2025-07-30 12:48:22,589 - [src.features] - INFO - Rows change: 787602 -> 702516 (-10.80%)
# 2025-07-30 12:48:22,589 - [src.features] - INFO - Features change: 21 -> 15 (-28.57%)

# %%
print(f"The number of columes before feature engineering: {len(df.columns)}")
print(f"The columns of original dataset: {df.columns}")
print("="*25, "*"*5, "="*25)
print(f"The number of columes after feature engineering: {len(processed_df.columns)}")
print(f"The columns of original dataset: {processed_df.columns}")
# Out:
# The number of columes before feature engineering: 21
# The columns of original dataset: Index(['Diabetes', 'HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker',
#        'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'HvyAlcoholConsump',
#        'AnyHealthcare', 'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth',
#        'DiffWalk', 'Sex', 'Age', 'Education', 'Income', 'Year'],
#       dtype='object')
# ========================= ***** =========================
# The number of columes after feature engineering: 15
# The columns of original dataset: Index(['HighBP', 'HighChol', 'BMI', 'Stroke', 'HeartDiseaseorAttack',
#        'PhysActivity', 'GenHlth', 'PhysHlth', 'DiffWalk', 'Age', 'Income',
#        'HlthScore', 'RiskScore', 'CardioRisk', 'Diabetes'],
#       dtype='object')

# %%
# Display the data information after feature engineering
processed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 702516 entries, 0 to 787601
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HighBP                702516 non-null  float64
#  1   HighChol              702516 non-null  float64
#  2   BMI                   702516 non-null  float64
#  3   Stroke                702516 non-null  float64
#  4   HeartDiseaseorAttack  702516 non-null  float64
#  5   PhysActivity          702516 non-null  float64
#  6   GenHlth               702516 non-null  float64
#  7   PhysHlth              702516 non-null  float64
#  8   DiffWalk              702516 non-null  float64
#  9   Age                   702516 non-null  float64
#  10  Income                702516 non-null  float64
#  11  HlthScore             702516 non-null  float64
#  12  RiskScore             702516 non-null  float64
#  13  CardioRisk            702516 non-null  float64
#  14  Diabetes              702516 non-null  float64
# dtypes: float64(15)
# memory usage: 85.8 MB

# %%
# The number of records on each class
processed_df["Diabetes"].value_counts()
# Out:
# Diabetes
# 0.0    574442
# 2.0    111184
# 1.0     16890
# Name: count, dtype: int64

# %% [markdown]
# ## **3. Split train and test data**

# %%
# Split the features and the target
X = df.drop("Diabetes", axis=1)
y = df["Diabetes"]

# %%
# Split training and testing set
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    train_size=TRAIN_SIZE, 
    random_state=RANDOM_STATE, 
    stratify=y
)
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (630081, 20)
# X_test shape: (157521, 20)
# y_train shape: (630081,)
# y_test shape: (157521,)

# %%
# The number of records of each class on training set
y_train.value_counts()
# Out:
# Diabetes
# 0.0    526293
# 2.0     90218
# 1.0     13570
# Name: count, dtype: int64

# %%
# The number of records of each class on testing set
y_test.value_counts()
# Out:
# Diabetes
# 0.0    131574
# 2.0     22554
# 1.0      3393
# Name: count, dtype: int64

# %% [markdown]
# ## **4. Data balancing**

# %% [markdown]
# ### **4.1 Over sampling**

# %%
# Initialize Over SamplerBalancer
over_sampling_balancer = OverSamplingBalancer()
# Out:
# 2025-07-30 12:47:39,905 - [src.balancing.over_sampler] - INFO - OverSamplingBalancer initialized successfully

# %% [markdown]
# #### **4.1.1 Random Over Sampling**

# %%
# Apply RandomOverSampling on training set
ros_X_train, ros_y_train = over_sampling_balancer.apply_random_oversampling(
    X=X_train,
    y=y_train,
    sampling_strategy=OVER_SAMPLING_STRATEGY
)
# Out:
# 2025-07-30 12:49:35,301 - [src.balancing.over_sampler] - INFO - Starting Random Over Sampling process...
# 2025-07-30 12:49:35,310 - [src.balancing.over_sampler] - INFO - Original class distribution:
# 2025-07-30 12:49:35,310 - [src.balancing.over_sampler] - INFO -   - Class 0.0: 526293 samples
# 2025-07-30 12:49:35,311 - [src.balancing.over_sampler] - INFO -   - Class 1.0: 13570 samples
# 2025-07-30 12:49:35,312 - [src.balancing.over_sampler] - INFO -   - Class 2.0: 90218 samples
# 2025-07-30 12:49:35,450 - [src.balancing.over_sampler] - INFO - New class distribution after Random Over Sampling:
# 2025-07-30 12:49:35,451 - [src.balancing.over_sampler] - INFO -   - Class 0.0: 526293 samples (+0)
# 2025-07-30 12:49:35,451 - [src.balancing.over_sampler] - INFO -   - Class 1.0: 50000 samples (+36430)
# 2025-07-30 12:49:35,452 - [src.balancing.over_sampler] - INFO -   - Class 2.0: 100000 samples (+9782)
# 2025-07-30 12:49:35,452 - [src.balancing.over_sampler] - INFO - Dataset size: 630081 -> 676293 samples (+46212)
# 2025-07-30 12:49:35,452 - [src.balancing.over_sampler] - INFO - Random Over Sampling completed successfully

# %%
# Check the number of samples on each class after balancing
ros_y_train.value_counts()
# Out:
# Diabetes
# 0.0    526293
# 2.0    100000
# 1.0     50000
# Name: count, dtype: int64

# %% [markdown]
# #### **4.1.2 SMOTE**

# %%
# Apply SMOTE balancer on training set
smote_X_train, smote_y_train = over_sampling_balancer.apply_smote(
    X=X_train,
    y=y_train,
    sampling_strategy=OVER_SAMPLING_STRATEGY
)
# Out:
# 2025-07-30 12:50:49,549 - [src.balancing.over_sampler] - INFO - Starting SMOTE process...
# 2025-07-30 12:50:49,559 - [src.balancing.over_sampler] - INFO - Original class distribution:
# 2025-07-30 12:50:49,560 - [src.balancing.over_sampler] - INFO -   - Class 0.0: 526293 samples
# 2025-07-30 12:50:49,561 - [src.balancing.over_sampler] - INFO -   - Class 1.0: 13570 samples
# 2025-07-30 12:50:49,562 - [src.balancing.over_sampler] - INFO -   - Class 2.0: 90218 samples
# 2025-07-30 12:50:57,391 - [src.balancing.over_sampler] - INFO - New class distribution after SMOTE:
# 2025-07-30 12:50:57,391 - [src.balancing.over_sampler] - INFO -   - Class 0.0: 526293 samples (+0 synthetic)
# 2025-07-30 12:50:57,392 - [src.balancing.over_sampler] - INFO -   - Class 1.0: 50000 samples (+36430 synthetic)
# 2025-07-30 12:50:57,392 - [src.balancing.over_sampler] - INFO -   - Class 2.0: 100000 samples (+9782 synthetic)
# 2025-07-30 12:50:57,393 - [src.balancing.over_sampler] - INFO - Dataset size: 630081 -> 676293 samples (+46212 synthetic)
# 2025-07-30 12:50:57,393 - [src.balancing.over_sampler] - INFO - SMOTE completed successfully

# %%
# Check the number of samples on each class after balancing
smote_y_train.value_counts()
# Out:
# Diabetes
# 0.0    526293
# 2.0    100000
# 1.0     50000
# Name: count, dtype: int64

# %% [markdown]
# ### **4.2 Under Sampling**

# %%
# Initialize UnderSamplingBalancer
under_sampling_balancer = UnderSamplingBalancer()
# Out:
# 2025-07-30 12:57:00,406 - [src.balancing.under_sampler] - INFO - UnderSamplingBalancer initialized successfully

# %% [markdown]
# #### **4.2.1 Random Under Sampling**

# %%
# Apply RandomUnderSampling on training test
rus_X_train, rus_y_train = under_sampling_balancer.apply_random_undersampling(
    X=X_train,
    y=y_train,
    sampling_strategy=UNDER_SAMPLING_STRATEGY
)
# Out:
# 2025-07-30 12:57:33,170 - [src.balancing.under_sampler] - INFO - Starting Random Under Sampling process...
# 2025-07-30 12:57:33,179 - [src.balancing.under_sampler] - INFO - Original class distribution:
# 2025-07-30 12:57:33,180 - [src.balancing.under_sampler] - INFO -   - Class 0.0: 526293 samples
# 2025-07-30 12:57:33,180 - [src.balancing.under_sampler] - INFO -   - Class 1.0: 13570 samples
# 2025-07-30 12:57:33,181 - [src.balancing.under_sampler] - INFO -   - Class 2.0: 90218 samples
# 2025-07-30 12:57:33,304 - [src.balancing.under_sampler] - INFO - New class distribution after Random Under Sampling:
# 2025-07-30 12:57:33,304 - [src.balancing.under_sampler] - INFO -   - Class 0.0: 300000 samples (-226293)
# 2025-07-30 12:57:33,305 - [src.balancing.under_sampler] - INFO -   - Class 1.0: 13570 samples (-0)
# 2025-07-30 12:57:33,305 - [src.balancing.under_sampler] - INFO -   - Class 2.0: 50000 samples (-40218)
# 2025-07-30 12:57:33,305 - [src.balancing.under_sampler] - INFO - Dataset size: 630081 -> 363570 samples (-266511)
# 2025-07-30 12:57:33,305 - [src.balancing.under_sampler] - INFO - Random Under Sampling completed successfully

# %%
# Check the number of samples after balancing
rus_y_train.value_counts()
# Out:
# Diabetes
# 0.0    300000
# 2.0     50000
# 1.0     13570
# Name: count, dtype: int64

# %% [markdown]
# #### **4.2.2 TomekLinks**

# %%
# Apply TomekLinks on training set
tomek_X_train, tokek_y_train = under_sampling_balancer.apply_tomek_links(
    X=X_train,
    y=y_train,
    sampling_strategy=[0],
    n_jobs=N_JOBS
)
# Out:
# 2025-07-30 12:58:14,237 - [src.balancing.under_sampler] - INFO - Starting Tomek Links process...
# 2025-07-30 12:58:14,246 - [src.balancing.under_sampler] - INFO - Original class distribution:
# 2025-07-30 12:58:14,247 - [src.balancing.under_sampler] - INFO -   - Class 0.0: 526293 samples
# 2025-07-30 12:58:14,247 - [src.balancing.under_sampler] - INFO -   - Class 1.0: 13570 samples
# 2025-07-30 12:58:14,248 - [src.balancing.under_sampler] - INFO -   - Class 2.0: 90218 samples
# 2025-07-30 13:08:04,626 - [src.balancing.under_sampler] - INFO - New class distribution after Tomek Links:
# 2025-07-30 13:08:04,627 - [src.balancing.under_sampler] - INFO -   - Class 0.0: 503934 samples (-22359 Tomek links)
# 2025-07-30 13:08:04,627 - [src.balancing.under_sampler] - INFO -   - Class 1.0: 13570 samples (unchanged)
# 2025-07-30 13:08:04,628 - [src.balancing.under_sampler] - INFO -   - Class 2.0: 90218 samples (unchanged)
# 2025-07-30 13:08:04,628 - [src.balancing.under_sampler] - INFO - Dataset size: 630081 -> 607722 samples (-22359 Tomek links)
# 2025-07-30 13:08:04,628 - [src.balancing.under_sampler] - INFO - Tomek Links processing completed successfully

# %%
# Check the number of samples after balancing
tokek_y_train.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Check the number of samples after balancing
# ----> 2 tokek_y_train.value_counts()
#
# NameError: name 'tokek_y_train' is not defined

# %% [markdown]
# ### **4.3 Hyprid**

# %%
hyprid_balancer = HybridSamplingBalancer()
# Out:
# 2025-07-20 13:44:10,436 - [src.balancing.hyprid] - INFO - HybridSamplingBalancer initialized successfully

# %% [markdown]
# #### **4.3.1 SMOTE + TomekLinks**

# %%
smote_tomek_X_train, smote_tomek_y_train = hyprid_balancer.apply_smote_tomek(
    X_train,
    y_train,
    OVER_SAMPLING_STRATEGY,
    n_jobs=os.cpu_count()
)
# Out:
# 2025-07-20 14:39:58,644 - [src.balancing.hyprid] - INFO - Starting SMOTETomek hybrid sampling process...
# 2025-07-20 14:39:58,653 - [src.balancing.hyprid] - INFO - Original class distribution:
# 2025-07-20 14:39:58,654 - [src.balancing.hyprid] - INFO -   - Class 0.0: 526321 samples
# 2025-07-20 14:39:58,655 - [src.balancing.hyprid] - INFO -   - Class 1.0: 13570 samples
# 2025-07-20 14:39:58,656 - [src.balancing.hyprid] - INFO -   - Class 2.0: 90225 samples
# 2025-07-20 14:58:42,967 - [src.balancing.hyprid] - INFO - New class distribution after SMOTETomek:
# 2025-07-20 14:58:42,969 - [src.balancing.hyprid] - INFO -   - Class 0.0: 509938 samples (-16383 net)
# 2025-07-20 14:58:42,970 - [src.balancing.hyprid] - INFO -   - Class 1.0: 49326 samples (+35756 net)
# 2025-07-20 14:58:42,970 - [src.balancing.hyprid] - INFO -   - Class 2.0: 84001 samples (-6224 net)
# 2025-07-20 14:58:42,971 - [src.balancing.hyprid] - INFO - Dataset size: 630116 -> 643265 samples (+13149)
# 2025-07-20 14:58:42,973 - [src.balancing.hyprid] - INFO - SMOTETomek processing completed successfully

# %%
smote_tomek_y_train.value_counts()
# Out:
# Diabetes
# 0.0    509938
# 2.0     84001
# 1.0     49326
# Name: count, dtype: int64

# %% [markdown]
# #### **4.3.2 SMOTE + ENN**

# %%
smoteenn_X_train, smoteenn_y_train = hyprid_balancer.apply_smote_enn(
    X_train,
    y_train,
    OVER_SAMPLING_STRATEGY,
    os.cpu_count()
)
# Out:
# 2025-07-20 14:58:43,022 - [src.balancing.hyprid] - INFO - Starting SMOTEENN hybrid sampling process...
# 2025-07-20 14:58:43,035 - [src.balancing.hyprid] - INFO - Original class distribution:
# 2025-07-20 14:58:43,037 - [src.balancing.hyprid] - INFO -   - Class 0.0: 526321 samples
# 2025-07-20 14:58:43,038 - [src.balancing.hyprid] - INFO -   - Class 1.0: 13570 samples
# 2025-07-20 14:58:43,040 - [src.balancing.hyprid] - INFO -   - Class 2.0: 90225 samples
# 2025-07-20 15:17:47,371 - [src.balancing.hyprid] - INFO - New class distribution after SMOTEENN:
# 2025-07-20 15:17:47,372 - [src.balancing.hyprid] - INFO -   - Class 0.0: 346080 samples (-180241 net)
# 2025-07-20 15:17:47,372 - [src.balancing.hyprid] - INFO -   - Class 1.0: 33113 samples (+19543 net)
# 2025-07-20 15:17:47,374 - [src.balancing.hyprid] - INFO -   - Class 2.0: 8812 samples (-81413 net)
# 2025-07-20 15:17:47,376 - [src.balancing.hyprid] - INFO - Dataset size: 630116 -> 388005 samples (-242111)
# 2025-07-20 15:17:47,377 - [src.balancing.hyprid] - INFO - SMOTEENN processing completed successfully

# %%
smoteenn_y_train.value_counts()
# Out:
# Diabetes
# 0.0    346080
# 1.0     33113
# 2.0      8812
# Name: count, dtype: int64

# %% [markdown]
# ## **3. Models**

# %% [markdown]
# ### **3.1 SGD Classifier**

# %%
sgd_model = DiabetesSGDClassifier(
    loss=SGD_LOSS,
    penalty=SGD_PENALTY,
    alpha=SGD_ALPHA,
    max_iter=SGD_MAX_ITER,
    random_state=RANDOM_STATE,
    learning_rate=SGD_LEARNING_RATE
)
sgd_model_info = sgd_model.get_model_info()

# %%
sgd_model_info

# %%
sgd_model.train(X_train, y_train)

# %%
sgd_y_pred = sgd_model.predict(X_test)

# %%
sgd_model.evaluate(y_test, sgd_y_pred)

# %%
sgd_prob = sgd_model.predict_proba(X)

# %%
plot_roc_auc(y, sgd_prob, "SGDClassifier")

# %% [markdown]
# ### **3.2 Logistic Regression**

# %%
lr_model = DiabetesLogisticRegression(C=LR_C, max_iter=LR_MAX_ITER, solver=LR_SOLVER)
lr_model_info = lr_model.get_model_info()

# %%
lr_model.train(X_train, y_train)

# %%
lr_y_pred = lr_model.predict(X_test)

# %%
lr_model.evaluate(y_test, lr_y_pred)

# %%
lr_prob = lr_model.predict_proba(X)

# %%
plot_roc_auc(y, lr_prob, "LogisticRegression")

# %% [markdown]
# ### **3.3 Naive Bayes**

# %%
nb_model = DiabetesNaiveBayes(
    nb_type=NB_TYPE,
    var_smoothing=NB_VAR_SMOOTHING,
    binarize=NB_BINARIZE,
    alpha=NB_ALPHA
)
nb_model_info = nb_model.get_model_info()

# %%
nb_model_info

# %%
nb_model.train(X_train, y_train)

# %%
nb_y_pred = nb_model.predict(X_test)

# %%
nb_model.evaluate(y_test, nb_y_pred)

# %%
nb_prob = nb_model.predict_proba(X)

# %%
plot_roc_auc(y, nb_prob, "NaiveBayes")

# %% [markdown]
# ### **3.4 Random Forest**

# %%
rf_model = DiabetesRandomForest(
    n_estimators=RF_N_ESTIMATORS,
    max_depth=RF_MAX_DEPTH,
    random_state=RANDOM_STATE,
)
rf_model_info = rf_model.get_model_info()

# %%
rf_model_info

# %%
rf_model.train(X_train, y_train)

# %%
rf_y_pred = rf_model.predict(X_test)

# %%
rf_model.evaluate(y_test, rf_y_pred)

# %%
rf_prob = rf_model.predict_proba(X)

# %%
plot_roc_auc(y, rf_prob, "RandomForest")

# %% [markdown]
# ## **4. Compare models**

# %%
models = {
    "SGDClassifier": sgd_model,
    "LogisticRegression": lr_model,
    "NaiveBayes": nb_model,
    "RandomForest": rf_model
}

compare_results = compare_models(models, X_test, y_test)

# %%
compare_results

# %%
df["Diabetes"].value_counts()
